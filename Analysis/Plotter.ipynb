# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
import os
hep.style.use("CMS")

# %%
# Get the list of all files and directories
path = "/home/tomas/Documents/UdeA_Results/DM"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
dir_list.sort(reverse = False)


dir_list.remove('pt_miss_histogram_monojet_BM_toy_my_1000_GeV_mDM_100_GeV_gDM_1.csv')#.remove('pt_miss_histogram_monojet_BM_toy_my_1000_GeV_mDM_400_GeV_gDM_1.csv')
dir_list.remove('pt_miss_histogram_monojet_BM_toy_my_1000_GeV_mDM_400_GeV_gDM_1.csv')
dir_list = ['pt_miss_histogram_monojet_BM_toy_my_500_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_550_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_600_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_650_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_700_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_750_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_800_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_850_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_900_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_950_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_1000_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_1050_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_1100_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_1150_GeV_mDM_10_GeV_gDM_1.csv',
             'pt_miss_histogram_monojet_BM_toy_my_1200_GeV_mDM_10_GeV_gDM_1.csv']
dir_list
# Out:
# Files and directories in ' /home/tomas/Documents/UdeA_Results/DM ' :
# ['pt_miss_histogram_monojet_BM_toy_my_500_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_550_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_600_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_650_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_700_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_750_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_800_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_850_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_900_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_950_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_1000_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_1050_GeV_mDM_10_GeV_gDM_1.csv',
#  'pt_miss_histogram_monojet_BM_toy_my_1100_GeV_mDM_10_GeV_gDM_1.csv',
# ...

# %%
labels = [f'$m(y)={i}$ GeV' for i in range(500, 1250, 50)]
labels
# Out:
# ['$m(y)=500$ GeV',
#  '$m(y)=550$ GeV',
#  '$m(y)=600$ GeV',
#  '$m(y)=650$ GeV',
#  '$m(y)=700$ GeV',
#  '$m(y)=750$ GeV',
#  '$m(y)=800$ GeV',
#  '$m(y)=850$ GeV',
#  '$m(y)=900$ GeV',
#  '$m(y)=950$ GeV',
#  '$m(y)=1000$ GeV',
#  '$m(y)=1050$ GeV',
#  '$m(y)=1100$ GeV',
#  '$m(y)=1150$ GeV',
#  '$m(y)=1200$ GeV']

# %%
f, axs = plt.subplots( figsize=(9, 7))
labs_sizes = 20

for i in range(len(dir_list[:5])):
    df = pd.read_csv(path+'/'+dir_list[i], index_col = 'Unnamed: 0')
    bins = list(df.bins_lower)
    bins.append(2000)
    hep.histplot(df.counts,
                 bins = bins,
                 ax = axs,
                 yerr = df.error ,
                 #color = 'b',
                 histtype = 'step',  
                 label = labels[i])

axs.set_xlabel('$p_T^{miss}$', fontsize = labs_sizes)
axs.set_ylabel('Events', fontsize = labs_sizes)
axs.set_xlim(140, 1000)
axs.set_ylim(1.5e1, 5.2e4)
#axs.set_yscale("log")
axs.legend(fontsize = 'xx-small', loc = 'upper right')
axs.set_title(r'$12.9 \,fb^{-1}(13 \,TeV)$', loc = 'right', fontsize = labs_sizes + 1)
plt.savefig('pt_miss_histogram_monojet_1');

# %%
f, axs = plt.subplots( figsize=(9, 7))
labs_sizes = 20

for i in range(len(dir_list[:5])):
    df = pd.read_csv(path+'/'+dir_list[i + 5], index_col = 'Unnamed: 0')
    bins = list(df.bins_lower)
    bins.append(2000)
    hep.histplot(df.counts,
                 bins = bins,
                 ax = axs,
                 yerr = df.error ,
                 #color = 'b',
                 histtype = 'step',  
                 label = labels[i+ 5])

axs.set_xlabel('$p_T^{miss}$', fontsize = labs_sizes)
axs.set_ylabel('Events', fontsize = labs_sizes)
axs.set_xlim(140, 1000)
axs.set_ylim(1.5e1, 2.2e4)
#axs.set_yscale("log")
axs.legend(fontsize = 'xx-small', loc = 'upper right')
axs.set_title(r'$12.9 \,fb^{-1}(13 \,TeV)$', loc = 'right', fontsize = labs_sizes + 1)
plt.savefig('pt_miss_histogram_monojet_2');

# %%
f, axs = plt.subplots( figsize=(9, 7))
labs_sizes = 20

for i in range(len(dir_list[:5])):
    df = pd.read_csv(path+'/'+dir_list[i + 10], index_col = 'Unnamed: 0')
    bins = list(df.bins_lower)
    bins.append(2000)
    hep.histplot(df.counts,
                 bins = bins,
                 ax = axs,
                 yerr = df.error ,
                 #color = 'b',
                 histtype = 'step',  
                 label = labels[i+ 10])

axs.set_xlabel('$p_T^{miss}$', fontsize = labs_sizes)
axs.set_ylabel('Events', fontsize = labs_sizes)
axs.set_xlim(140, 1000)
axs.set_ylim(1.5e1, 1.2e4)
#axs.set_yscale("log")
axs.legend(fontsize = 'xx-small', loc = 'upper right')
axs.set_title(r'$12.9 \,fb^{-1}(13 \,TeV)$', loc = 'right', fontsize = labs_sizes + 1)
plt.savefig('pt_miss_histogram_monojet_3');
